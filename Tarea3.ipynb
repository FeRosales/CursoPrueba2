# %%
# Examen 1: Puntaje de Concierto
Escribe una función en Python llamada `calcular_puntaje` que reciba el número de notas perfectas y el multiplicador de combo de un concierto de Togenashi Togeari, y devuelva el puntaje total (multiplicando ambos valores).

# %%
def calcular_puntaje(notas_perfectas, combo):
       ### BEGIN SOLUTION
       return notas_perfectas * combo
       ### END SOLUTION

# %%
assert calcular_puntaje(100, 2) == 200
   assert calcular_puntaje(50, 5) == 250
   assert calcular_puntaje(0, 10) == 0
   print("¡Respuesta correcta, el concierto fue un éxito!")
